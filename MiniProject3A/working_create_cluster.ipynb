# %% [markdown]
# # Creating a cluster/slice

# %% [markdown]
# ## Please read carefully all the instructions. Specially the comments given in each cell. These comments are pertinent to run a cluster successfully.
#
# If the fabric environment is not set please read through the topic <code>FABRIC Environment Setup</code> in <code>start_here.ipynb</code> notebook given under <code>jupyter-example</code> folder in fabric's JupyterHub.
#
# <b> At first read the comments in the cell and then only run the cell. </b>

# %% [markdown]
# # Setup configuration for Using Fabric Testbed via FABlib API
#
# The following notebook can be used to configure your Jupyter environment.  The product of running this notebook are the following:
#
# - `fabric_rc`:  File used to configure a FABlib application.
# - `fabric_bastion_key`: Fabric Bastion key pair. In order to minimize security incidents on FABRIC, access to VMs and other resources administered by users is controlled using a bastion host. You will need to set up an ssh keypair that will be used to jump through the bastion host to your VMs and other resources. This keypair is unique to you an
#   d is only used to set up ssh proxy connections through the bastion host to your FABRIC resources. More information about how to access your experiment through the bastion host can be found [here](https://learn.fabric-testbed.net/knowledge-base/logging-into-fabric-vms/).
# - `slice_key` and `slice_key.pub`: Sliver Key pair.
# - `ssh_config`: File used to ssh from from a terminal to FABRIC VM by jumping through the FABRIC bastion host.

# %% [markdown]
# ## Set Project ID and generate the configuration
#
# Edit the following cell by entering your Project ID for the FABRIC Project to use in your Jupyter container.
#
# - The Project ID can be from any of your projects. The ID can be found in the 'Basic Info' tab for each of the [projects](https://portal.fabric-testbed.net/experiments#projects) in the FABRIC portal.

# %%
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

# Update this line to specify your project id
project_id = "7db31408-b695-427c-8856-8761292228b6"

# Uncomment the line below if using 'FABRIC Tutorials' Project
#project_id="a7818636-1fa1-4e77-bb03-d171598b0862"

fablib = fablib_manager(project_id=project_id)
# Out:
# User: cslgbt@missouri.edu bastion key is valid!
# Configuration is valid

# %% [markdown]
# ## Display the configuration

# %%
fablib.show_config();
# Out:
# <style type="text/css">
# #T_df5a8 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_df5a8 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_df5a8 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_df5a8_row0_col0, #T_df5a8_row0_col1, #T_df5a8_row1_col0, #T_df5a8_row1_col1, #T_df5a8_row2_col0, #T_df5a8_row2_col1, #T_df5a8_row3_col0, #T_df5a8_row3_col1, #T_df5a8_row4_col0, #T_df5a8_row4_col1, #T_df5a8_row5_col0, #T_df5a8_row5_col1, #T_df5a8_row6_col0, #T_df5a8_row6_col1, #T_df5a8_row7_col0, #T_df5a8_row7_col1, #T_df5a8_row8_col0, #T_df5a8_row8_col1, #T_df5a8_row9_col0, #T_df5a8_row9_col1, #T_df5a8_row10_col0, #T_df5a8_row10_col1, #T_df5a8_row11_col0, #T_df5a8_row11_col1, #T_df5a8_row12_col0, #T_df5a8_row12_col1, #T_df5a8_row13_col0, #T_df5a8_row13_col1, #T_df5a8_row14_col0, #T_df5a8_row14_col1, #T_df5a8_row15_col0, #T_df5a8_row15_col1, #T_df5a8_row16_col0, #T_df5a8_row16_col1, #T_df5a8_row17_col0, #T_df5a8_row17_col1, #T_df5a8_row18_col0, #T_df5a8_row18_col1, #T_df5a8_row19_col0, #T_df5a8_row19_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_df5a8">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_df5a8_row0_col0" class="data row0 col0" >Orchestrator</td>
#       <td id="T_df5a8_row0_col1" class="data row0 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_df5a8_row1_col0" class="data row1 col0" >Credential Manager</td>
#       <td id="T_df5a8_row1_col1" class="data row1 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_df5a8_row2_col0" class="data row2 col0" >Core API</td>
#       <td id="T_df5a8_row2_col1" class="data row2 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_df5a8_row3_col0" class="data row3 col0" >Artifact Manager</td>
#       <td id="T_df5a8_row3_col1" class="data row3 col1" >artifacts.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_df5a8_row4_col0" class="data row4 col0" >Token File</td>
#       <td id="T_df5a8_row4_col1" class="data row4 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_df5a8_row5_col0" class="data row5 col0" >Project ID</td>
#       <td id="T_df5a8_row5_col1" class="data row5 col1" >7db31408-b695-427c-8856-8761292228b6</td>
#     </tr>
#     <tr>
#       <td id="T_df5a8_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_df5a8_row6_col1" class="data row6 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_df5a8_row7_col0" class="data row7 col0" >Bastion Username</td>
#       <td id="T_df5a8_row7_col1" class="data row7 col1" >cslgbt_0000451422</td>
#     </tr>
#     <tr>
#       <td id="T_df5a8_row8_col0" class="data row8 col0" >Bastion Private Key File</td>
#       <td id="T_df5a8_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_df5a8_row9_col0" class="data row9 col0" >Slice Public Key File</td>
#       <td id="T_df5a8_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_df5a8_row10_col0" class="data row10 col0" >Slice Private Key File</td>
#       <td id="T_df5a8_row10_col1" class="data row10 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_df5a8_row11_col0" class="data row11 col0" >Sites to avoid</td>
#       <td id="T_df5a8_row11_col1" class="data row11 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_df5a8_row12_col0" class="data row12 col0" >SSH Command Line</td>
#       <td id="T_df5a8_row12_col1" class="data row12 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_df5a8_row13_col0" class="data row13 col0" >Log Level</td>
#       <td id="T_df5a8_row13_col1" class="data row13 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_df5a8_row14_col0" class="data row14 col0" >Log File</td>
#       <td id="T_df5a8_row14_col1" class="data row14 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_df5a8_row15_col0" class="data row15 col0" >Bastion SSH Config File</td>
#       <td id="T_df5a8_row15_col1" class="data row15 col1" >/home/fabric/work/fabric_config/ssh_config</td>
#     </tr>
#     <tr>
#       <td id="T_df5a8_row16_col0" class="data row16 col0" >Fabric Meta Data Release Tag</td>
#       <td id="T_df5a8_row16_col1" class="data row16 col1" >main</td>
#     </tr>
#     <tr>
#       <td id="T_df5a8_row17_col0" class="data row17 col0" >Version</td>
#       <td id="T_df5a8_row17_col1" class="data row17 col1" >1.9.3</td>
#     </tr>
#     <tr>
#       <td id="T_df5a8_row18_col0" class="data row18 col0" >Data directory</td>
#       <td id="T_df5a8_row18_col1" class="data row18 col1" >/tmp/fablib</td>
#     </tr>
#     <tr>
#       <td id="T_df5a8_row19_col0" class="data row19 col0" >Project Name</td>
#       <td id="T_df5a8_row19_col1" class="data row19 col1" >CI4Neuroscience</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Validate the configuration;
# - Checks the validity of the bastion keys and regenerates them if they are expired
# - Generates Sliver keys if they do not exist already

# %%
fablib.verify_and_configure()
# Out:
# User: cslgbt@missouri.edu bastion key is valid!
# Configuration is valid
# Please save the config!

# %% [markdown]
# ## Save the configuration for subsequent use

# %%
fablib.save_config()

# %% [markdown]
# ## STEP-1

# %%
# Run this cell
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager
try:
    fablib = fablib_manager()
    fablib.show_config()
except Exception as e:
    print(f"Exception: {e}")
# Out:
# User: cslgbt@missouri.edu bastion key is valid!
# Configuration is valid
# <style type="text/css">
# #T_64fbd tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_64fbd tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_64fbd caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_64fbd_row0_col0, #T_64fbd_row0_col1, #T_64fbd_row1_col0, #T_64fbd_row1_col1, #T_64fbd_row2_col0, #T_64fbd_row2_col1, #T_64fbd_row3_col0, #T_64fbd_row3_col1, #T_64fbd_row4_col0, #T_64fbd_row4_col1, #T_64fbd_row5_col0, #T_64fbd_row5_col1, #T_64fbd_row6_col0, #T_64fbd_row6_col1, #T_64fbd_row7_col0, #T_64fbd_row7_col1, #T_64fbd_row8_col0, #T_64fbd_row8_col1, #T_64fbd_row9_col0, #T_64fbd_row9_col1, #T_64fbd_row10_col0, #T_64fbd_row10_col1, #T_64fbd_row11_col0, #T_64fbd_row11_col1, #T_64fbd_row12_col0, #T_64fbd_row12_col1, #T_64fbd_row13_col0, #T_64fbd_row13_col1, #T_64fbd_row14_col0, #T_64fbd_row14_col1, #T_64fbd_row15_col0, #T_64fbd_row15_col1, #T_64fbd_row16_col0, #T_64fbd_row16_col1, #T_64fbd_row17_col0, #T_64fbd_row17_col1, #T_64fbd_row18_col0, #T_64fbd_row18_col1, #T_64fbd_row19_col0, #T_64fbd_row19_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_64fbd">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_64fbd_row0_col0" class="data row0 col0" >Orchestrator</td>
#       <td id="T_64fbd_row0_col1" class="data row0 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_64fbd_row1_col0" class="data row1 col0" >Credential Manager</td>
#       <td id="T_64fbd_row1_col1" class="data row1 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_64fbd_row2_col0" class="data row2 col0" >Core API</td>
#       <td id="T_64fbd_row2_col1" class="data row2 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_64fbd_row3_col0" class="data row3 col0" >Artifact Manager</td>
#       <td id="T_64fbd_row3_col1" class="data row3 col1" >artifacts.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_64fbd_row4_col0" class="data row4 col0" >Token File</td>
#       <td id="T_64fbd_row4_col1" class="data row4 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_64fbd_row5_col0" class="data row5 col0" >Project ID</td>
#       <td id="T_64fbd_row5_col1" class="data row5 col1" >7db31408-b695-427c-8856-8761292228b6</td>
#     </tr>
#     <tr>
#       <td id="T_64fbd_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_64fbd_row6_col1" class="data row6 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_64fbd_row7_col0" class="data row7 col0" >Bastion Username</td>
#       <td id="T_64fbd_row7_col1" class="data row7 col1" >cslgbt_0000451422</td>
#     </tr>
#     <tr>
#       <td id="T_64fbd_row8_col0" class="data row8 col0" >Bastion Private Key File</td>
#       <td id="T_64fbd_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_64fbd_row9_col0" class="data row9 col0" >Slice Public Key File</td>
#       <td id="T_64fbd_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_64fbd_row10_col0" class="data row10 col0" >Slice Private Key File</td>
#       <td id="T_64fbd_row10_col1" class="data row10 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_64fbd_row11_col0" class="data row11 col0" >Sites to avoid</td>
#       <td id="T_64fbd_row11_col1" class="data row11 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_64fbd_row12_col0" class="data row12 col0" >SSH Command Line</td>
#       <td id="T_64fbd_row12_col1" class="data row12 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_64fbd_row13_col0" class="data row13 col0" >Log Level</td>
#       <td id="T_64fbd_row13_col1" class="data row13 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_64fbd_row14_col0" class="data row14 col0" >Log File</td>
#       <td id="T_64fbd_row14_col1" class="data row14 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_64fbd_row15_col0" class="data row15 col0" >Bastion SSH Config File</td>
#       <td id="T_64fbd_row15_col1" class="data row15 col1" >/home/fabric/work/fabric_config/ssh_config</td>
#     </tr>
#     <tr>
#       <td id="T_64fbd_row16_col0" class="data row16 col0" >Fabric Meta Data Release Tag</td>
#       <td id="T_64fbd_row16_col1" class="data row16 col1" >main</td>
#     </tr>
#     <tr>
#       <td id="T_64fbd_row17_col0" class="data row17 col0" >Version</td>
#       <td id="T_64fbd_row17_col1" class="data row17 col1" >1.9.3</td>
#     </tr>
#     <tr>
#       <td id="T_64fbd_row18_col0" class="data row18 col0" >Data directory</td>
#       <td id="T_64fbd_row18_col1" class="data row18 col1" >/tmp/fablib</td>
#     </tr>
#     <tr>
#       <td id="T_64fbd_row19_col0" class="data row19 col0" >Project Name</td>
#       <td id="T_64fbd_row19_col1" class="data row19 col1" >CI4Neuroscience</td>
#     </tr>
#   </tbody>
# </table>

# %%
# slice_name='GPU_Variant_Calling_FIU'
# node_name='Node2'
# slice = fablib.get_slice(slice_name)
# node = slice.get_node(node_name)
# node.os_reboot()

# %%
# Run this cell
# To find all the available resources at this time
# run the cell below for easier readability 
try:
    resources = fablib.list_sites()
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_02d06 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_02d06 th {
#   text-align: left;
# }
# #T_02d06 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_02d06 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_02d06 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T
_col9, #T_02d06_row2_col10, #T_02d06_row2_col11, #T_02d06_row2_col12, #T_02d06_row2_col13, #T_02d06_row2_col14, #T_02d06_row2_col15, #T_02d06_row2_col16, #T_02d06_row2_col17, #T_02d06_row2_col18, #T_02d06_row2_col19, #T_02d06_row2_col20, #T_02d06_row2_col21, #T_02d06_row2_col22, #T_02d06_row2_col23, #T_02d06_row2_col24, #T_02d06_row2_col25, #T_02d06_row2_col26, #T_02d06_row2_col27, #T_02d06_row2_col28, #T_02d06_row2_col29, #T_02d06_row2_col30, #T_02d06_row2_col31, #T_02d06_row2_col32, #T_02d06_row2_col33, #T_02d06_row2_col34, #T_02d06_row2_col35, #T_02d06_row2_col36, #T_02d06_row2_col37, #T_02d06_row2_col38, #T_02d06_row2_col39, #T_02d06_row2_col40, #T_02d06_row2_col41, #T_02d06_row2_col42, #T_02d06_row2_col43, #T_02d06_row2_col44, #T_02d06_row2_col45, #T_02d06_row2_col46, #T_02d06_row2_col47, #T_02d06_row2_col48, #T_02d06_row2_col49, #T_02d06_row2_col50, #T_02d06_row2_col51, #T_02d06_row2_col52, #T_02d06_row2_col53, #T_02d06_row2_col54, #T_02d06_row2_col55, #T_02d06_row2_col56, #T_02d06_row2_col57, #T_02d06_row3_col0, #T_02d06_row3_col1, #T_02d06_row3_col2, #T_02d06_row3_col3, #T_02d06_row3_col4, #T_02d06_row3_col5, #T_02d06_row3_col6, #T_02d06_row3_col7, #T_02d06_row3_col8, #T_02d06_row3_col9, #T_02d06_row3_col10, #T_02d06_row3_col11, #T_02d06_row3_col12, #T_02d06_row3_col13, #T_02d06_row3_col14, #T_02d06_row3_col15, #T_02d06_row3_col16, #T_02d06_row3_col17, #T_02d06 ...

# %%
# for easier readability of available resources
import pandas as pd 
pd.DataFrame(resources.data)[['Hosts','CPUs','Name','Cores Available','Ram Available','Tesla T4 Available','RTX6000 Available','A30 Available','A40 Available']]
# Out:
#     Hosts  CPUs    Name  Cores Available  Ram Available  Tesla T4 Available  \
# 0       2     4    NEWY               49            320                   0
# 1       5    10    UCSD              -55            666                   2
# 2       6    12    STAR               85            764                   2
# 3      18    36   EDUKY            73513           7738                   0
# 4       5    10    UTAH              149           1034                   0
# 5       5    10    RUTG              200           1198                   0
# 6       3     6    PRIN              104            866                   0
# 7       3     6     SRI              192            586                   0
# 8       5    10    TACC               92            310                   0
# 9       2     4    SEAT              134            692                   0
# 10      5    10     MAX              124            798                   2
# 11      3     6    WASH              190            570                   0
# 12      3     6    MICH              108            466                   0
# 13      3     6    SALT              212            962                   2
# 14      3     6   BRIST               37            582                   0
# 15      3     6    AMST              106            794                   0
# 16      3     6    MASS              166            746                   0
# 17      6    12    CERN              336           1140                   0
# 18      3     6    NCSA               78            474                   0
# 19      3     6    KANS               40            730                   0
# 20      5    10     FIU              165            882                   0
# 21      5    10  GATECH              326           1246                   0
# 22      3     6    CLEM              238            946                   0
# 23      3     6    DALL               72            660                   0
# 24      3     6    LOSA               58            410                   0
# 25      3     6    INDI               34            570                   0
# 26      3     6     PSC              316           1162                   0
# 27      5    10    HAWI              140           1334                   0
# 28      3     6    TOKY              252           1026                   0
# 29      5    10     GPN               32           1142                   0
# 30      2     4    ATLA               44            224                   0
# 31      1     2     EDC               76            366                   0
#
#     RTX6000 Available  A30 Available  A40 Available
# 0                   0              0              0
# 1                   0              0              0
# 2                   1              0              0
# 3                   0              0              0
# 4                   0              0              0
# 5                   0              0              0
# 6                   0              2              0
# 7                   0              1              0
# 8                   0              0              0
# 9                   0              0              0
# 10                  0              0              0
# 11                  2              0              0
# 12                  3              0              0
# 13                  2              0              0
# 14                  0              1              0
# 15                  0              1              0
# 16                  1              0              0
# 17                  0              1              0
# 18                  3              0              0
# 19                  0              1              0
# 20                  1              0              0
# 21                  0              1              0
# 22                  0              0              0
# 23                  2              0              0
# 24                  0              0              0
# 25                  0              1              0
# 26                  0              0              0
# 27                  0              0              0
# 28                  0              1              0
# 29                  2              0              0
# 30                  0              0              0
# 31                  0              0              0

# %% [markdown]
# ## Step-2: Creating a cluster from an instance type.

# %%
# Run this cell
# Initialize the variables appropriately. 
# Number of nodes in the cluster.
num_nodes=3

# Give a cluster name
slice_name='MiniProject3A_Cluster'

# Make it True if you want to include persistence storage to a single node. KEEP IT FALSE FOR THE TIME BEING.
storage=False

# get attached to the cluster. By default adding NVMe is false.
add_NVMe = False

# Make it True if you want to include GPUs to different nodes in the cluster [depends on availability].
add_gpu=False

# By default master node will not have GPUs in it. For CPU only cluster False means lower resources then the workers.
master_gpu=False

# If only t4 gpu needs to be added.
add_t4=False

# If only rtx gpu needs to be added.
add_rtx=False

# If only rtx gpu needs to be added.
add_a40=False


# Site name, pick one site from the above list of resources.
site='EDUKY'

# Select node resource:- It follows the pattern fabric.c#N.m#N.d#N , where c:cores, m:primary memory, d:disk and #N: capacity.
# eg: fabric.c4.m8.d50 means cores:4, Memory:8Gb, disk:50Gb  
# List of node instance type is provided in - https://github.com/fabric-testbed/InformationModel/blob/master/fim/slivers/data/instance_sizes.json
#instance_worker='fabric.c24.m128.d500'
instance_worker = "fabric.c8.m16.d100"

# The resources of master node. It is better to be less than the worker nodes.
instance_master = "fabric.c8.m16.d100"

# Operation system, Linux distribution e.g. default_ubuntu_18, default_ubuntu_20, etc.
image='default_ubuntu_20'

# %%
import pandas as pd

try:
    json_format=fablib.list_sites(output='json',quiet=True)
except Exception as e:
    print(f"Exception: {e}")

sites_df=pd.read_json(json_format)
site_df=sites_df[sites_df['name']==site]
type_t4=site_df['tesla_t4_available'].values
type_rtx=site_df['rtx6000_available'].values
type_a40=site_df['a40_available'].values

nvme_available=site_df['nvme_available'].values
print("Number of Nvidia t4 available now at",site,"is:", type_t4[0])
print("Number of Nvidia rtx6000 available now at",site,"is:", type_rtx[0])
print("Number of Nvidia A40 available now at",site,"is:", type_a40[0])
print("Number of NVMe available now at",site,"is:", nvme_available[0])

max_type_t4 = type_t4[0]
max_type_rtx = type_rtx[0]
max_type_a40 = type_a40[0]

total_gpus = max_type_t4 + max_type_rtx + max_type_a40
# Out:
# Number of Nvidia t4 available now at GPN is: 3
# Number of Nvidia rtx6000 available now at GPN is: 6
# Number of Nvidia A40 available now at GPN is: 0
# Number of NVMe available now at GPN is: 16
# /tmp/ipykernel_79/299778379.py:8: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   sites_df=pd.read_json(json_format)

# %%
# The max available GPU for the chosen site is mentioned above, to change it please make changes to the variables below.
# By default initialized with the available GPUs for the site.

custom_number_of_t4 = max_type_t4
custom_number_of_rtx = max_type_rtx
custom_number_of_a40 = max_type_a40


# custom_number_of_t4 = 3
# custom_number_of_rtx =4

if custom_number_of_t4 < max_type_t4 or custom_number_of_rtx < max_type_rtx:
    max_type_t4 = custom_number_of_t4
    max_type_rtx = custom_number_of_rtx
    total_gpus = max_type_t4 + max_type_rtx
print(total_gpus)
gpu_names=[]

for i in range(1,total_gpus+1):
    gpu_names.append("GPU_{0}".format(i))
 
print(gpu_names)
temp_t4=max_type_t4
temp_rtx=max_type_rtx

######################################################
#####                  NVMe                      #####
######################################################

# Assumption: If the number of available NVMes' are less than the number of cluster node minus the master NVMes' will not

if nvme_available >= num_nodes-1 and add_NVMe == True:
    add_NVMe = True
print(add_NVMe)
# Out:
# 9
# ['GPU_1', 'GPU_2', 'GPU_3', 'GPU_4', 'GPU_5', 'GPU_6', 'GPU_7', 'GPU_8', 'GPU_9']
# True

# %%
# Run this cell

node_names=[]
nic_names=[]
iface_names=[]
nvme_names=[]
network_name='cluster_network'
storage_name = 'gaf-storage'

for i in range(1,num_nodes+1):
    node_names.append("Node{0}".format(i))
    nic_names.append("Nic{0}".format(i))
    iface_names.append("iface{0}".format(i))
    nvme_names.append("nvme{0}".format(i))

print(node_names)
print(nic_names)
print(iface_names)
print(nvme_names)
# Out:
# ['Node1', 'Node2', 'Node3']
# ['Nic1', 'Nic2', 'Nic3']
# ['iface1', 'iface2', 'iface3']
# ['nvme1', 'nvme2', 'nvme3']

# %%
# Only run when persistence storage needed to be attached. 
if storage == True:
    import traceback
    from plugins import Plugins
    try:
        Plugins.load()
    except Exception as e:
        traceback.print_exc()
print(temp_t4)
print(temp_rtx)
# Out:
# 3
# 6

# %%
print(add_a40)
# Out:
# False

# %%
# # Run this cell, Visit the link below to find different instance type options. 
# # Read the comments carefully given below and make changes as necessary. 
# ## Allocating 2 A40 GPUs on VM1 (worker node) and VM0 as managing node
# try:
#     slice=fablib.new_slice(name=slice_name)
#     for i in range(num_nodes):
#         if master_gpu == False and i == 0:
#             node=slice.add_node(name=node_names[i],
#                                 site=site, 
#                                 instance_type=instance_master,
#                                 image=image)
#             iface_names[i]=node.add_component(model='NIC_Basic', name=node_names[i]).get_interfaces()[0]
#         else:
#             node=slice.add_node(name=node_names[i],
#                                 site=site,
#                                 instance_type=instance_worker,
#                                 image=image)
#             iface_names[i]=node.add_component(model='NIC_Basic',name=node_names[i]).get_interfaces()[0]
#             if add_gpu == True:
#                 print(i)
#                 if add_a40 == True  and i == 1: # Attach 2-A40 GPUs on VM1 machine
#                     node.add_component(model='GPU_A40', name=gpu_names[i-1])
#                     node.add_component(model='GPU_A40', name=gpu_names[i-2])
#                     print("allocated 2 A40 GPUs")
#                     type_a40 = type_a40 - 2 
#                 else: 
#                     print("No GPUs available")
#             if add_NVMe == True:
#                 node.add_component(model='NVME_P4510', name=nvme_names[i-1])
#             else:
#                 print("NVMe not avail")
# except Exception as e:
#     print(f'Exception: {e}')

# %%
# # Run this cell, Visit the link below to find different instance type options. 
# # Read the comments carefully given below and make changes as necessary. 

# try:
#     slice=fablib.new_slice(name=slice_name)
    
#     for i in range(num_nodes):
#         if master_gpu == False and i == 0:
#             node=slice.add_node(name=node_names[i],
#                                 site=site, 
#                                 instance_type=instance_master,
#                                 image=image)
#             iface_names[i]=node.add_component(model='NIC_Basic', name=node_names[i]).get_interfaces()[0]
        
#         else:
#             node=slice.add_node(name=node_names[i],
#                                 site=site,
#                                 instance_type=instance_worker,
#                                 image=image)
#             iface_names[i]=node.add_component(model='NIC_Basic',name=node_names[i]).get_interfaces()[0]
            
#             if add_gpu == True:
#                 print(i)
#                 if add_t4 == True and temp_t4 > 1 and i==1: # allocating 2 T4
#                     node.add_component(model='GPU_TeslaT4', name=gpu_names[i-1])
#                     node.add_component(model='GPU_TeslaT4', name=gpu_names[i-2])
#                     temp_t4 = temp_t4 - 2 
#                     print("allocated 2T4")
#                 if add_t4 == True and temp_t4 > 0 and i==2: # allocating 1 T4
#                     node.add_component(model='GPU_TeslaT4', name=gpu_names[i-1])
#                     temp_t4 = temp_t4 - 1 
#                     print("allocated 1T4")
#                 # if add_rtx == True and temp_rtx >2 and i==3: # allocating 3rtx
#                 #     node.add_component(model='GPU_RTX6000',name=gpu_names[i-1])
#                 #     node.add_component(model='GPU_RTX6000',name=gpu_names[i-2])
#                 #     node.add_component(model='GPU_RTX6000',name=gpu_names[i-3])
#                 #     temp_rtx = temp_rtx - 3
#                 #     print("allocated 3rtx")
#                 if add_rtx == True and temp_rtx >1 and i==3: # allocating 2 T4
#                     node.add_component(model='GPU_RTX6000',name=gpu_names[i-1])
#                     node.add_component(model='GPU_RTX6000',name=gpu_names[i-2])
#                     temp_rtx = temp_rtx - 2
#                     print("allocated 2rtx")
#                 if add_rtx == True and temp_rtx >0 and i==4: # allocating 1 rtx
#                     node.add_component(model='GPU_RTX6000',name=gpu_names[i-1])
#                     temp_rtx = temp_rtx - 1
#                     print("allocated 1rtx")
#                 else: 
#                     print("No GPUs available")
#             if add_NVMe == True:
#                 node.add_component(model='NVME_P4510', name=nvme_names[i-1])
# except Exception as e:
#     print(f'Exception: {e}')

# %%
# Run this cell, Visit the link below to find different instance type options. 
# Read the comments carefully given below and make changes as necessary. 

try:
    slice=fablib.new_slice(name=slice_name)
    
    for i in range(num_nodes):
        if master_gpu == False and i == 0:
            node=slice.add_node(name=node_names[i],
                                site=site, 
                                instance_type=instance_master,
                                image=image)
            iface_names[i]=node.add_component(model='NIC_Basic', name=node_names[i]).get_interfaces()[0]
        
        else:
            node=slice.add_node(name=node_names[i],
                                site=site,
                                instance_type=instance_worker,
                                image=image)
            iface_names[i]=node.add_component(model='NIC_Basic',name=node_names[i]).get_interfaces()[0]
            
            if add_gpu == True:
                print(i)
                if add_t4 == True and temp_t4 > 1 and i==1: # allocating 2 T4
                    node.add_component(model='GPU_TeslaT4', name=gpu_names[i-1])
                    node.add_component(model='GPU_TeslaT4', name=gpu_names[i-2])
                    temp_t4 = temp_t4 - 2 
                    print("allocated 2T4")
                if add_t4 == True and temp_t4 > 0 and i==2: # allocating 1 T4
                    node.add_component(model='GPU_TeslaT4', name=gpu_names[i-1])
                    temp_t4 = temp_t4 - 1 
                    print("allocated 1T4")
                if add_rtx == True and temp_rtx >2 and i==3: # allocating 3rtx
                    node.add_component(model='GPU_RTX6000',name=gpu_names[i-1])
                    node.add_component(model='GPU_RTX6000',name=gpu_names[i-2])
                    node.add_component(model='GPU_RTX6000',name=gpu_names[i-3])
                    temp_rtx = temp_rtx - 3
                    print("allocated 3rtx")
                if add_rtx == True and temp_rtx >1 and i==4: # allocating 2 T4
                    node.add_component(model='GPU_RTX6000',name=gpu_names[i-1])
                    node.add_component(model='GPU_RTX6000',name=gpu_names[i-2])
                    temp_rtx = temp_rtx - 2
                    print("allocated 2rtx")
                if add_rtx == True and temp_rtx >0 and i==5: # allocating 1 rtx
                    node.add_component(model='GPU_RTX6000',name=gpu_names[i-1])
                    temp_rtx = temp_rtx - 1
                    print("allocated 1rtx")
                else: 
                    print("No GPUs available")
            if add_NVMe == True:
                node.add_component(model='NVME_P4510', name=nvme_names[i-1])
            else:
                print("NVMe not avail")
except Exception as e:
    print(f'Exception: {e}')
# Out:
# NVMe not avail
# NVMe not avail

# %%
# Run this cell
try:
    net_cluster=slice.add_l2network(name=network_name, interfaces=iface_names[:])
except Exception as e:
    print(f"Exception: {e}")

# %%
# Run this cell
# If this cell get executed successfully then IP address of the nodes will be displayed which can be used to ssh into the respective nodes.
# If there is an error while creating the slice/cluster, repeat from the third code cell block.
try:
    slice.submit()
except Exception as e:
    print(f'Exception: {e}')
# Out:
# Retry: 11, Time: 262 sec
# <style type="text/css">
# #T_86044 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_86044 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_86044 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_86044_row0_col0, #T_86044_row0_col1, #T_86044_row1_col0, #T_86044_row1_col1, #T_86044_row2_col0, #T_86044_row2_col1, #T_86044_row3_col0, #T_86044_row3_col1, #T_86044_row4_col0, #T_86044_row4_col1, #T_86044_row5_col0, #T_86044_row6_col0, #T_86044_row6_col1, #T_86044_row7_col0, #T_86044_row7_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_86044_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_86044">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_86044_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_86044_row0_col1" class="data row0 col1" >6a4cd873-dc9b-4ea4-921b-2a6939cd209c</td>
#     </tr>
#     <tr>
#       <td id="T_86044_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_86044_row1_col1" class="data row1 col1" >MiniProject3A_Cluster</td>
#     </tr>
#     <tr>
#       <td id="T_86044_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_86044_row2_col1" class="data row2 col1" >2026-03-06 00:22:42 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_86044_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_86044_row3_col1" class="data row3 col1" >2026-03-05 00:22:42 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_86044_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_86044_row4_col1" class="data row4 col1" >7db31408-b695-427c-8856-8761292228b6</td>
#     </tr>
#     <tr>
#       <td id="T_86044_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_86044_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#     <tr>
#       <td id="T_86044_row6_col0" class="data row6 col0" >Email</td>
#       <td id="T_86044_row6_col1" class="data row6 col1" >cslgbt@missouri.edu</td>
#     </tr>
#     <tr>
#       <td id="T_86044_row7_col0" class="data row7 col0" >UserId</td>
#       <td id="T_86044_row7_col1" class="data row7 col1" >7fa5070e-304e-4e07-9b7e-824b45c39b7e</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_bf938 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_bf938 th {
#   text-align: left;
# }
# #T_bf938 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_bf938 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_bf938 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_bf938_row0_col0, #T_bf938_row0_col1, #T_bf938_row0_col2, #T_bf938_row0_col3, #T_bf938_row0_col4, #T_bf938_row0_col5, #T_bf938_row0_col6, #T_bf938_row0_col7, #T_bf938_row0_col8, #T_bf938_row0_col9, #T_bf938_row0_col10, #T_bf938_row0_col13, #T_bf938_row0_col14, #T_bf938_row0_col15, #T_bf938_row1_col0, #T_bf938_row1_col1, #T_bf938_row1_col2, #T_bf938_row1_col3, #T_bf938_row1_col4, #T_bf938_row1_col5, #T_bf938_row1_col6, #T_bf938_row1_col7, #T_bf938_row1_col8, #T_bf938_row1_col9, #T_bf938_row1_col10, #T_bf938_row1_col13, #T_bf938_row1_col14, #T_bf938_row1_col15, #T_bf938_row2_col0, #T_bf938_row2_col1, #T_bf938_row2_col2, #T_bf938_row2_col3, #T_bf938_row2_col4, #T_bf938_row2_col5, #T_bf938_row2_col6, #T_bf938_row2_col7, #T_bf938_row2_col8, #T_bf938_row2_col9, #T_bf938_row2_col10, #T_bf938_row2_col13, #T_bf938_row2_col14, #T_bf938_row2_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_bf938_row0_col11, #T_bf938_row1_col11, #T_bf938_row2_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_bf938_row0_col12, #T_bf938_row1_col12, #T_bf938_row2_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_bf938">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_bf938_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_bf938_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_bf938_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_bf938_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_bf938_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_bf938_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_bf938_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_bf938_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_bf938_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_bf938_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_bf938_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_bf938_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T
td>
#     </tr>
#   </tbody>
# </table>
# Time to print interfaces 265 seconds

# %% [markdown]
# ## Step-3: Configuring the network and setting up the cluster

# %%
# try:
#     slice=fablib.get_slice(name="GPU_Variant_Calling_FIU") # Put the cluster name that you want to delete
#     # slice.delete()
# except Exception as e:
#     print(f"Exception: {e}")

# %%
from ipaddress import IPv4Network
import time

subnet = IPv4Network("192.168.1.0/24")
available_ips = list(subnet)[1:]

time.sleep(20)

for node in slice.get_nodes():

    iface = node.get_interface(network_name=network_name)

    if iface is None:
        print(node.get_name(), "interface not found")
        continue

    ip_addr = available_ips.pop(0)

    print("Assigning", ip_addr, "to", node.get_name())

    # Reset interface first
    node.execute(f"sudo ifconfig {iface.get_os_interface()} down")

    iface.ip_addr_add(addr=ip_addr, subnet=subnet)

    node.execute(f"sudo ifconfig {iface.get_os_interface()} up")

    time.sleep(2)
# Out:
# Assigning 192.168.1.1 to Node1
# Assigning 192.168.1.2 to Node2
# Assigning 192.168.1.3 to Node3

# %%
node1 = slice.get_node(name="Node1")
print(node1.execute("ping -c 3 192.168.1.3")[0])
# Out:
# PING 192.168.1.3 (192.168.1.3) 56(84) bytes of data.
# 64 bytes from 192.168.1.3: icmp_seq=1 ttl=64 time=1.15 ms
# 64 bytes from 192.168.1.3: icmp_seq=2 ttl=64 time=0.207 ms
# 64 bytes from 192.168.1.3: icmp_seq=3 ttl=64 time=0.120 ms
#
# --- 192.168.1.3 ping statistics ---
# 3 packets transmitted, 3 received, 0% packet loss, time 2023ms
# rtt min/avg/max/mdev = 0.120/0.492/1.149/0.465 ms
# PING 192.168.1.3 (192.168.1.3) 56(84) bytes of data.
# 64 bytes from 192.168.1.3: icmp_seq=1 ttl=64 time=1.15 ms
# 64 bytes from 192.168.1.3: icmp_seq=2 ttl=64 time=0.207 ms
# 64 bytes from 192.168.1.3: icmp_seq=3 ttl=64 time=0.120 ms
#
# --- 192.168.1.3 ping statistics ---
# 3 packets transmitted, 3 received, 0% packet loss, time 2023ms
# rtt min/avg/max/mdev = 0.120/0.492/1.149/0.465 ms

# %%
ping -c 3 192.168.1.2
ping -c 3 192.168.1.3
# Out:
#   Cell In[29], line 1
#     ping -c 3 192.168.1.2
#             ^
# SyntaxError: invalid syntax

# %%
#Run this cell
from ipaddress import IPv4Address, IPv4Network
try:
    subnet=IPv4Network("192.168.1.0/24")
    available_ips=list(subnet)[1:]
except Exception as e:
    print(f"Exception: {e}")

# %%
try:
   for node in slice.get_nodes():
       node_iface=node.get_interface(network_name=network_name)
       # print(node_iface)
       stdout, stderr = node.execute(f'ip addr show {node_iface.get_os_interface()}')
       # print(stdout,stderr)
except Exception as e:
   print(f"Exception: {e}")
# Out:
# 3: enp7s0: <BROADCAST,MULTICAST,UP,LOWER_UP> mtu 1500 qdisc mq state UP group default qlen 1000
#     link/ether 02:57:4f:f8:dd:d4 brd ff:ff:ff:ff:ff:ff
#     inet6 fe80::57:4fff:fef8:ddd4/64 scope link
#        valid_lft forever preferred_lft forever
# 3: enp7s0: <BROADCAST,MULTICAST,UP,LOWER_UP> mtu 1500 qdisc mq state UP group default qlen 1000
#     link/ether 0a:66:dd:4c:52:a4 brd ff:ff:ff:ff:ff:ff
#     inet6 fe80::866:ddff:fe4c:52a4/64 scope link
#        valid_lft forever preferred_lft forever
# 3: enp7s0: <BROADCAST,MULTICAST,UP,LOWER_UP> mtu 1500 qdisc mq state UP group default qlen 1000
#     link/ether 0a:8f:75:75:3c:5e brd ff:ff:ff:ff:ff:ff
#     inet6 fe80::88f:75ff:fe75:3c5e/64 scope link
#        valid_lft forever preferred_lft forever

# %%
#Run this cell
#%%capture
try:
    for node in slice.get_nodes():
        node_iface=node.get_interface(network_name=network_name)
        node_IP_addr=available_ips.pop(0)
        node_iface.ip_addr_add(addr=node_IP_addr, subnet=subnet)
        stdout, stderr = node.execute(f'ip addr show {node_iface.get_os_interface()}')
        _, _ = node.execute('sudo apt-get update')
        stdout, stderr = node.execute('sudo apt install net-tools')        
        stdout, stderr = node.execute(f'sudo ifconfig {node_iface.get_os_interface()} up')
except Exception as e:
    print(f"Exception: {e}")
# Out:
# 3: enp7s0: <BROADCAST,MULTICAST,UP,LOWER_UP> mtu 1500 qdisc mq state UP group default qlen 1000
#     link/ether 02:57:4f:f8:dd:d4 brd ff:ff:ff:ff:ff:ff
#     inet 192.168.1.1/24 scope global enp7s0
#        valid_lft forever preferred_lft forever
#     inet6 fe80::57:4fff:fef8:ddd4/64 scope link
#        valid_lft forever preferred_lft forever
# Get:1 http://security.ubuntu.com/ubuntu focal-security InRelease [128 kB]
# Get:2 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [3564 kB]
# Hit:3 http://nova.clouds.archive.ubuntu.com/ubuntu focal InRelease
# Get:4 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates InRelease [128 kB]
# Get:5 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports InRelease [128 kB]
# Get:6 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 Packages [8628 kB]
# Get:7 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe Translation-en [5124 kB]
# Get:8 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 c-n-f Metadata [265 kB]
# Get:9 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 Packages [144 kB]
# Get:10 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse Translation-en [104 kB]
# Get:11 http://security.ubuntu.com/ubuntu focal-security/main Translation-en [518 kB]
# Get:12 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 c-n-f Metadata [9136 B]
# Get:13 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3957 kB]
# Get:14 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1040 kB]
# Get:15 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main Translation-en [600 kB]
# Get:16 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1262 kB]
# Get:17 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe Translation-en [303 kB]
# Get:18 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 c-n-f Metadata [29.3 kB]
# Get:19 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [29.7 kB]
# Get:20 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse Translation-en [8316 B]
# Get:21 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 c-n-f Metadata [688 B]
# Get:22 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 Packages [45.7 kB]
# Get:23 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main Translation-en [16.3 kB]
# Get:24 http://security.ubuntu.com/ubuntu focal-security/universe Translation-en [221 kB]
# Get:25 http://security.ubuntu.com/ubuntu focal-security/universe amd64 c-n-f Metadata [22.4 kB]
# Get:26 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [26.6 kB]
# Get:27 http://security.ubuntu.com/ubuntu focal-security/multiverse Translation-en [6448 B]
# Get:28 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 c-n-f Metadata [1420 B]
# Get:29 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/restricted amd64 c-n-f Metadata [116 B]
# Get:30 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 c-n-f Metadata [604 B]
# Get:31 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 Packages [25.0 kB]
# Get:32 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe Translation-en [16.3 kB]
# Get:33 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 c-n-f Metadata [880 B]
# Get:34 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/multiverse amd64 c-n-f Metadata [116 B]
# Fetched 26.4 MB in 5s (5069 kB/s)
# Reading package lists...
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   net-tools
# 0 upgraded, 1 newly installed, 0 to remove and 21 not upgraded.
# Need to get 192 kB of archives.
# After this operation, 856 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 net-tools amd64 1.60+git20180626.aebd88e-1ubuntu1.3 [192 kB]
# debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Fetched 192 kB in 1s (313 kB/s)
# Selecting previously unselected package net-tools.
# (Reading database ... 64241 files and directories currently installed.)
# Preparing to unpack .../net-tools_1.60+git20180626.aebd88e-1ubuntu1.3_amd64.deb ...
# Unpacking net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Setting up net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Processing triggers for man-db (2.9.1-1) ...
# 3: enp7s0: <BROADCAST,MULTICAST,UP,LOWER_UP> mtu 1500 qdisc mq state UP group default qlen 1000
#     link/ether 0a:66:dd:4c:52:a4 brd ff:ff:ff:ff:ff:ff
#     inet 192.168.1.2/24 scope global enp7s0
#        valid_lft forever preferred_lft forever
#     inet6 fe80::866:ddff:fe4c:52a4/64 scope link
#        valid_lft forever preferred_lft forever
# Hit:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal InRelease
# Get:2 http://security.ubuntu.com/ubuntu focal-security InRelease [128 kB]
# Get:3 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates InRelease [128 kB]
# Get:4 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [3564 kB]
# Get:5 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports InRelease [128 kB]
# Get:6 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 Packages [8628 kB]
# Get:7 http://security.ubuntu.com/ubuntu focal-security/main Translation-en [518 kB]
# Get:8 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1040 kB]
# Get:9 http://security.ubuntu.com/ubuntu focal-security/universe Translation-en [221 kB]
# Get:10 http://security.ubuntu.com/ubuntu focal-security/universe amd64 c-n-f Metadata [22.4 kB]
# Get:11 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [26.6 kB]
# Get:12 http://security.ubuntu.com/ubuntu focal-security/multiverse Translation-en [6448 B]
# Get:13 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 c-n-f Metadata [604 B]
# Get:14 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe Translation-en [5124 kB]
# Get:15 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 c-n-f Metadata [265 kB]
# Get:16 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 Packages [144 kB]
# Get:17 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse Translation-en [104 kB]
# Get:18 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 c-n-f Metadata [9136 B]
# Get:19 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3957 kB]
# Get:20 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main Translation-en [600 kB]
# Get:21 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1262 kB]
# Get:22 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe Translation-en [303 kB]
# Get:23 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 c-n-f Metadata [29.3 kB]
# Get:24 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [29.7 kB]
# Get:25 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse Translation-en [8316 B]
# Get:26 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 c-n-f Metadata [688 B]
# Get:27 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 Packages [45.7 kB]
# Get:28 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main Translation-en [16.3 kB]
# Get:29 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 c-n-f Metadata [1420 B]
# Get:30 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/restricted amd64 c-n-f Metadata [116 B]
# Get:31 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 Packages [25.0 kB]
# Get:32 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe Translation-en [16.3 kB]
# Get:33 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 c-n-f Metadata [880 B]
# Get:34 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/multiverse amd64 c-n-f Metadata [116 B]
# Fetched 26.4 MB in 4s (6045 kB/s)
# Reading package lists...
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   net-tools
# 0 upgraded, 1 newly installed, 0 to remove and 21 not upgraded.
# Need to get 192 kB of archives.
# After this operation, 856 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 net-tools amd64 1.60+git20180626.aebd88e-1ubuntu1.3 [192 kB]
# debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Fetched 192 kB in 1s (215 kB/s)
# Selecting previously unselected package net-tools.
# (Reading database ... 64241 files and directories currently installed.)
# Preparing to unpack .../net-tools_1.60+git20180626.aebd88e-1ubuntu1.3_amd64.deb ...
# Unpacking net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Setting up net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Processing triggers for man-db (2.9.1-1) ...
# 3: enp7s0: <BROADCAST,MULTICAST,UP,LOWER_UP> mtu 1500 qdisc mq state UP group default qlen 1000
#     link/ether 0a:8f:75:75:3c:5e brd ff:ff:ff:ff:ff:ff
#     inet 192.168.1.3/24 scope global enp7s0
#        valid_lft forever preferred_lft forever
#     inet6 fe80::88f:75ff:fe75:3c5e/64 scope link
#        valid_lft forever preferred_lft forever
# Hit:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal InRelease
# Get:2 http://security.ubuntu.com/ubuntu focal-security InRelease [128 kB]
# Get:3 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates InRelease [128 kB]
# Get:4 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [3564 kB]
# Get:5 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports InRelease [128 kB]
# Get:6 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 Packages [8628 kB]
# Get:7 http://security.ubuntu.com/ubuntu focal-security/main Translation-en [518 kB]
# Get:8 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1040 kB]
# Get:9 http://security.ubuntu.com/ubuntu focal-security/universe Translation-en [221 kB]
# Get:10 http://security.ubuntu.com/ubuntu focal-security/universe amd64 c-n-f Metadata [22.4 kB]
# Get:11 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [26.6 kB]
# Get:12 http://security.ubuntu.com/ubuntu focal-security/multiverse Translation-en [6448 B]
# Get:13 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 c-n-f Metadata [604 B]
# Get:14 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe Translation-en [5124 kB]
# Get:15 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 c-n-f Metadata [265 kB]
# Get:16 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 Packages [144 kB]
# Get:17 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse Translation-en [104 kB]
# Get:18 http://nova.clouds.archive.ubuntu.com/ubuntu focal/multiverse amd64 c-n-f Metadata [9136 B]
# Get:19 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3957 kB]
# Get:20 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main Translation-en [600 kB]
# Get:21 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1262 kB]
# Get:22 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe Translation-en [303 kB]
# Get:23 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 c-n-f Metadata [29.3 kB]
# Get:24 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [29.7 kB]
# Get:25 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse Translation-en [8316 B]
# Get:26 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 c-n-f Metadata [688 B]
# Get:27 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 Packages [45.7 kB]
# Get:28 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main Translation-en [16.3 kB]
# Get:29 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/main amd64 c-n-f Metadata [1420 B]
# Get:30 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/restricted amd64 c-n-f Metadata [116 B]
# Get:31 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 Packages [25.0 kB]
# Get:32 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe Translation-en [16.3 kB]
# Get:33 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/universe amd64 c-n-f Metadata [880 B]
# Get:34 http://nova.clouds.archive.ubuntu.com/ubuntu focal-backports/multiverse amd64 c-n-f Metadata [116 B]
# Fetched 26.4 MB in 4s (6650 kB/s)
# Reading package lists...
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   net-tools
# 0 upgraded, 1 newly installed, 0 to remove and 21 not upgraded.
# Need to get 192 kB of archives.
# After this operation, 856 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 net-tools amd64 1.60+git20180626.aebd88e-1ubuntu1.3 [192 kB]
# debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Fetched 192 kB in 1s (222 kB/s)
# Selecting previously unselected package net-tools.
# (Reading database ... 64241 files and directories currently installed.)
# Preparing to unpack .../net-tools_1.60+git20180626.aebd88e-1ubuntu1.3_amd64.deb ...
# Unpacking net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Setting up net-tools (1.60+git20180626.aebd88e-1ubuntu1.3) ...
# Processing triggers for man-db (2.9.1-1) ...

# %%
#Run this cell
# If the ping is successful, that means the nodes are connected properly if there is any error then may need to recreate the cluster or further have to look into it. 
try:
    node1=slice.get_node(name='Node1')
    stdout,stderr=node1.execute(f' ping -c 3 192.168.1.2')
    print(stdout)
    print(stderr)
except Exception as e:
    print(f'Exception: {e}')
# Out:
# PING 192.168.1.2 (192.168.1.2) 56(84) bytes of data.
# 64 bytes from 192.168.1.2: icmp_seq=1 ttl=64 time=0.269 ms
# 64 bytes from 192.168.1.2: icmp_seq=2 ttl=64 time=0.100 ms
# 64 bytes from 192.168.1.2: icmp_seq=3 ttl=64 time=0.093 ms
#
# --- 192.168.1.2 ping statistics ---
# 3 packets transmitted, 3 received, 0% packet loss, time 2041ms
# rtt min/avg/max/mdev = 0.093/0.154/0.269/0.081 ms
# PING 192.168.1.2 (192.168.1.2) 56(84) bytes of data.
# 64 bytes from 192.168.1.2: icmp_seq=1 ttl=64 time=0.269 ms
# 64 bytes from 192.168.1.2: icmp_seq=2 ttl=64 time=0.100 ms
# 64 bytes from 192.168.1.2: icmp_seq=3 ttl=64 time=0.093 ms
#
# --- 192.168.1.2 ping statistics ---
# 3 packets transmitted, 3 received, 0% packet loss, time 2041ms
# rtt min/avg/max/mdev = 0.093/0.154/0.269/0.081 ms

# %%
# Run this cell
# Function to create a file that contains IPs and hostnames related to it.

def append_line(file_path,text):
    with open(file_path,"a+") as file_des:
        file_des.seek(0)
        data=file_des.read(-1)
        if len(data)>0:
            file_des.write("\n")
        file_des.write(text)

# %%
# Run this cell

import os

if os.path.isfile('/home/fabric/work/hosts') or os.path.isfile('/home/fabric/work/ips.txt') or os.path.isfile('/home/fabric/work/workers'):
    os.system("rm /home/fabric/work/hosts")
    os.system("rm /home/fabric/work/ips.txt")
    os.system("rm /home/fabric/work/workers")    
else:
    print("does not exist")

if os.path.isfile('/home/fabric/work/gpu_ips.txt'):
    os.system("rm /home/fabric/work/gpu_ips.txt")
    
#os.system("rm /home/fabric/work/ips.txt")
# Out:
# does not exist

# %%
# Run this cell

# Capturing the IP addresses, this step needs to be integrated with the IP assigning stage, coded above. Or it may stay independent.
import os

i=1
local_host="127.0.0.1 localhost"
path_to_host_file="/home/fabric/work/hosts"
path_to_ip_file="/home/fabric/work/ips.txt"
path_to_worker_ip="/home/fabric/work/workers"
path_to_gpu_ips="/home/fabric/work/gpu_ips.txt"
gpu_name="NVIDIA"

append_line(path_to_host_file,local_host)

try:
    for node in slice.get_nodes():
        stdout, stderr=node.execute("hostname -I")
        IP=stdout.split(" ")[1]
        node_name="node{0}".format(i)
        vm_names="vm{0}".format(i-1)
        append_line(path_to_ip_file,IP)
        
        stdout, stderr=node.execute("hostname")
        line=IP+" "+node_name+" "+vm_names+" "+stdout
        append_line(path_to_host_file,line)
      
    
        if(i>1):
            append_line(path_to_worker_ip,vm_names)
            #append_line(path_to_worker_ip,IP)
        
        print(line)
        print(stderr)
        
        stdout_gpu, _=node.execute('lspci | grep NVIDIA')   
        if gpu_name in stdout_gpu:
            stdout_ip, _=node.execute('hostname -I')
            ip=stdout_ip.split(" ")[1]
            append_line(path_to_gpu_ips,ip)
            #print(ip)
        
        i=i+1
except Exception as e:
    print(f"Exception: {e}")
    
print(IP)
# Out:
# 10.30.6.56 192.168.1.1 2610:1e0:1700:206:f816:3eff:feb2:c6c3
# Node1
# 192.168.1.1 node1 vm0 Node1
#
#
# 10.30.6.225 192.168.1.2 2610:1e0:1700:206:f816:3eff:fe6d:504
# Node2
# 192.168.1.2 node2 vm1 Node2
#
#
# 10.30.9.37 192.168.1.3 2610:1e0:1700:206:f816:3eff:fefc:52bd
# Node3
# 192.168.1.3 node3 vm2 Node3
#
#
# 192.168.1.3

# %%
# Run this cell
try:
    for node in slice.get_nodes():
        stdout, stderr=node.execute(f'sudo cp /etc/hosts /etc/hosts_backup') # if you run the command twice the back up will be overwritten, a conditional block should be written
        output_host_copy=node.upload_file(path_to_host_file,"/home/ubuntu/hosts")
        output_ip_copy=node.upload_file(path_to_ip_file,"/home/ubuntu/ips.txt")
        output_worker_copy=node.upload_file(path_to_worker_ip,"/home/ubuntu/workers")
        stdout_host_copy,stderr_host_copy=node.execute(f'sudo cp /home/ubuntu/hosts /etc/hosts')
        if os.path.isfile('/home/fabric/work/gpu_ips.txt'):
            output_gpu_copy=node.upload_file(path_to_gpu_ips,"/home/ubuntu/gpu_ips.txt")
        print(stderr)
        print(stderr_host_copy)
except Exception as e:
    print(f"Exception : {e}")

# %%
# Run this cell

import os

output=os.system('ssh-keygen -q -t rsa -N "" -f /home/fabric/work/id_rsa > /dev/null 2>&1')

# %%
# Run this cell

try:
    for node in slice.get_nodes():
        output_private=node.upload_file("/home/fabric/work/id_rsa","/home/ubuntu/.ssh/id_rsa")
        output_public=node.upload_file("/home/fabric/work/id_rsa.pub","/home/ubuntu/.ssh/id_rsa.pub")
        
        stdout, stderr=node.execute(f' cat /home/ubuntu/.ssh/id_rsa.pub >> /home/ubuntu/.ssh/authorized_keys')
        stdout, stderr=node.execute(f' chmod 600 /home/ubuntu/.ssh/id_rsa*')
        
        print(output_private)
        print(output_public)
        print(stderr)
        #print(stdout)
        
except Exception as e:
    print(f"Exception: {e}")
# Out:
# -rw-rw-r--   1 1000     1000         2655 05 Mar 00:58 ?
# -rw-rw-r--   1 1000     1000          613 05 Mar 00:58 ?
#
# -rw-rw-r--   1 1000     1000         2655 05 Mar 00:58 ?
# -rw-rw-r--   1 1000     1000          613 05 Mar 00:58 ?
#
# -rw-rw-r--   1 1000     1000         2655 05 Mar 00:58 ?
# -rw-rw-r--   1 1000     1000          613 05 Mar 00:58 ?

# %%
# Run this cell. This is the last cell to run. Please read the comments in the next few cells to know how to extend the lease time and how to delete a slice/cluster. 

from ipaddress import ip_address, IPv6Address
try:
    for node in slice.get_nodes():
        if type(ip_address(node.get_management_ip())) is IPv6Address:
            node.upload_file("/home/fabric/work/nat64.sh", "/home/ubuntu/nat64.sh")
            #stdout, stderr=node.execute(f' chmod +x /home/ubuntu/nat64.sh && sudo bash /home/ubuntu/nat64.sh')
            stdout, stderr=node.execute(f' chmod +x /home/ubuntu/nat64.sh && sudo bash /home/ubuntu/nat64.sh > /dev/null 2>&1')
            print(stdout)
            print(stderr)
except Exception as e:
    print(f"Exception: {e}")
# Out:
# Exception: [Errno 2] No such file or directory: '/home/fabric/work/nat64.sh'

# %% [markdown]
# ## Step-4: Deleting and extending lease of a slice

# %%
# # Run this cell ONLY when you want to delete the cell
# # To delete a slice/cluster.
# try:
#     slice=fablib.get_slice(name="AVAH") # Put the cluster name that you want to delete
#     slice.delete()
# except Exception as e:
#     print(f"Exception: {e}")

# %%
# # Run this cell ONLY when you want to exted the time of the slice. Or to extend the lease time of the slice/cluster.

# import datetime
# slice_name='demo' # Give the cluster/slice name that you want to extend

# #Set end host to now plus 1 day
# new_end_date = (datetime.datetime.utcnow() + datetime.timedelta(days=7)).strftime("%Y-%m-%d %H:%M:%S %z")
# #new_end_date = (datetime.now(timezone.utc) + timedelta(days=6)).strftime("%Y-%m-%d %H:%M:%S %z")
# print(type(new_end_date), new_end_date)
# try:
#     slice=fablib.get_slice(name=slice_name)
#     slice.renew('2023-05-31 18:04:26 +0000') # Give the new lease end date and time of the slice. One can increase it by 7 days from the day of creation of the slice/cluster. 
    
#     #print(f"Lease End (UTC)        : {slice.get_lease_end()}")
# except Exception as e:
#     print(f"Exception: {e}")

# %%
# # Run this cell ONLY to observe the new lease time.

# slice_name='cluster_exp' # Give the slice/cluster name that you just extended. 
# try:
#     slice = fablib.get_slice(name=slice_name)
#     print(f"{slice}")
# except Exception as e:
#     print(f"Exception: {e}")

# %%
# # Run this cell ONLY to observe the new lease time.

# slice_name='cluster_gpu' # Give the slice/cluster name that you just extended. 
# try:
#     slice = fablib.get_slice(name=slice_name)
#     gpu_name="NVIDIA"
#     for node in slice.get_nodes():
#         #stdout, stderr=node.execute(f'sudo cp /etc/hosts /etc/hosts_backup') # if you run the command twice the back up will be overwritten, a conditional block should be written
#         stdout_gpu, _=node.execute('lspci | grep NVIDIA')   
#         if gpu_name in stdout_gpu:
#             stdout_ip, _=node.execute('hostname -I')
#             ip=stdout_ip.split(" ")[1]
#             print(ip)
# except Exception as e:
#     print(f"Exception: {e}")
